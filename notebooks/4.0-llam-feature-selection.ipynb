# %% [markdown]
# # Feature selection

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from turkish_music_emotion.feature_selection import FeatureSelector

# Initialize the FeatureSelector
data_dir = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))
selector = FeatureSelector(data_dir)

# Perform feature selection
selected_features = selector.select_features()

# Save the selected features
selector.save_selected_features(selected_features)
# Out:
# 2024-10-13 22:17:57.560 | INFO     | turkish_music_emotion.config:<module>:11 - PROJ_ROOT path is: /Users/larguelles/Documents/2 - Areas/mna/mlops/proyecto
# Original number of features: 50
# Features after variance threshold: 50
# Features after correlation analysis: 43
# Top 20 features by mutual information: ['_HarmonicChangeDetectionFunction_Std', '_HarmonicChangeDetectionFunction_PeriodAmp', '_Zero-crossingrate_Mean', '_Eventdensity_Mean', '_Pulseclarity_Mean', '_AttackTime_Mean', '_Fluctuation_Mean', '_HarmonicChangeDetectionFunction_Mean', '_Rolloff_Mean', '_MFCC_Mean_2', '_Chromagram_Mean_7', '_Chromagram_Mean_3', '_MFCC_Mean_1', '_MFCC_Mean_4', '_Tempo_Mean', '_MFCC_Mean_13', '_MFCC_Mean_7', '_MFCC_Mean_3', '_Chromagram_Mean_6', '_MFCC_Mean_6']
# Top 20 features by random forest importance: ['_HarmonicChangeDetectionFunction_Std', '_HarmonicChangeDetectionFunction_PeriodAmp', '_Zero-crossingrate_Mean', '_Fluctuation_Mean', '_Pulseclarity_Mean', '_Eventdensity_Mean', '_HarmonicChangeDetectionFunction_Mean', '_AttackTime_Mean', '_MFCC_Mean_1', '_MFCC_Mean_2', '_MFCC_Mean_4', '_MFCC_Mean_7', '_MFCC_Mean_3', '_Chromagram_Mean_7', '_Rolloff_Mean', '_Roughness_Slope', '_Chromagram_Mean_9', '_Chromagram_Mean_12', '_RMSenergy_Mean', '_AttackTime_Slope']
# Number of features after combining MI and RF: 25
# Feature selection completed. Selected features saved to '/Users/larguelles/Documents/2 - Areas/mna/mlops/proyecto/data/processed/feature_selected_data.csv'
#
# Final selected features:
# ['_MFCC_Mean_2', '_MFCC_Mean_13', '_Eventdensity_Mean', '_RMSenergy_Mean', '_Rolloff_Mean', '_Chromagram_Mean_9', '_Pulseclarity_Mean', '_Chromagram_Mean_3', '_MFCC_Mean_7', '_MFCC_Mean_3', '_HarmonicChangeDetectionFunction_Mean', '_Roughness_Slope', '_HarmonicChangeDetectionFunction_PeriodAmp', '_AttackTime_Slope', '_Zero-crossingrate_Mean', '_Fluctuation_Mean', '_MFCC_Mean_6', '_Chromagram_Mean_6', '_Tempo_Mean', '_AttackTime_Mean', '_MFCC_Mean_1', '_HarmonicChangeDetectionFunction_Std', '_MFCC_Mean_4', '_Chromagram_Mean_12', '_Chromagram_Mean_7']
