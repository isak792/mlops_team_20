# %% [markdown]
# # Pre-processing

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from turkish_music_emotion.features import DataPreprocessor

# Initialize the DataPreprocessor
data_dir = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))
preprocessor = DataPreprocessor(data_dir)

# Preprocess the data
preprocessor.preprocess_data()

# Save the processed data
preprocessor.save_processed_data()

# Print summary statistics
preprocessor.print_summary_statistics()

# Check for remaining high skewness or kurtosis
preprocessor.check_remaining_skewness_kurtosis()
# Out:
# 2024-10-13 22:14:26.238 | INFO     | turkish_music_emotion.config:<module>:11 - PROJ_ROOT path is: /Users/larguelles/Documents/2 - Areas/mna/mlops/proyecto
# Original _Fluctuation_Mean:
# Skewness: 2.880
# Kurtosis: 12.553
#
# Transformed _Fluctuation_Mean:
# Skewness: -0.054
# Kurtosis: 0.583
# Original _Roughness_Mean:
# Skewness: 2.076
# Kurtosis: 6.633
#
# Transformed _Roughness_Mean:
# Skewness: -0.028
# Kurtosis: -0.216
# Original _AttackTime_Mean:
# Skewness: 3.370
# Kurtosis: 16.880
#
# Transformed _AttackTime_Mean:
# Skewness: 0.174
# Kurtosis: 0.021
# Original _Pulseclarity_Mean:
# Skewness: 1.156
# Kurtosis: 1.184
#
# Transformed _Pulseclarity_Mean:
# Skewness: 0.111
# Kurtosis: -0.811
# Original _Spectralskewness_Mean:
# Skewness: 2.270
# Kurtosis: 8.988
#
# Transformed _Spectralskewness_Mean:
# Skewness: -0.017
# Kurtosis: 0.283
# Original _Spectralkurtosis_Mean:
# Skewness: 7.941
# Kurtosis: 88.547
#
# Transformed _Spectralkurtosis_Mean:
# Skewness: 0.071
# Kurtosis: -0.447
# Original _Spectralflatness_Mean:
# Skewness: 1.480
# Kurtosis: 5.088
#
# Transformed _Spectralflatness_Mean:
# Skewness: 0.016
# Kurtosis: -0.296
# Original _Chromagram_Mean_2:
# Skewness: 1.202
# Kurtosis: 0.411
#
# Transformed _Chromagram_Mean_2:
# Skewness: 0.293
# Kurtosis: -1.328
# Original _Chromagram_Mean_4:
# Skewness: 1.480
# Kurtosis: 1.444
#
# Transformed _Chromagram_Mean_4:
# Skewness: 0.361
# Kurtosis: -1.291
# Original _Chromagram_Mean_6:
# Skewness: 1.110
# Kurtosis: 0.170
#
# Transformed _Chromagram_Mean_6:
# Skewness: 0.283
# Kurtosis: -1.373
# Original _Chromagram_Mean_7:
# Skewness: 1.330
# Kurtosis: 0.900
#
# Transformed _Chromagram_Mean_7:
# Skewness: 0.285
# Kurtosis: -1.259
# Original _HarmonicChangeDetectionFunction_PeriodEntropy:
# Skewness: -1.475
# Kurtosis: 7.461
#
# Transformed _HarmonicChangeDetectionFunction_PeriodEntropy:
# Skewness: 0.111
# Kurtosis: 1.493
# Preprocessing completed. Fully processed data saved to '/Users/larguelles/Documents/2 - Areas/mna/mlops/proyecto/data/processed/Acoustic_Features_Processed.csv'
#
# Summary statistics of processed data:
#        _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# count       400.000000       400.000000         400.000000   400.000000
# mean          0.134650         0.553605          -0.002532   123.682020
# std           0.064368         0.050750           0.980294    34.234344
# min           0.010000         0.302000          -2.764919    48.284000
# 25%           0.085000         0.523000          -0.593919   101.490250
# 50%           0.128000         0.553000           0.029777   120.132500
# 75%           0.174000         0.583250           0.619452   148.986250
# max           0.431000         0.703000           2.635005   195.026000
#
#        _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  \
# count    400.000000    400.000000    400.000000    400.000000    400.000000
# mean       2.456422      0.071890      0.488065      0.030465      0.178897
# std        0.799262      0.537865      0.294607      0.275839      0.195230
# min        0.323000     -3.484000     -0.870000     -1.636000     -0.494000
# 25%        1.948500     -0.262750      0.281250     -0.117000      0.061250
# 50%        2.389500      0.068500      0.464500      0.044500      0.181000
# 75%        2.860250      0.413250      0.686000      0.198250      0.288500
# max        5.996000      1.937000      1.622000      1.126000      1.055000
#
#        _MFCC_Mean_6  ...  _Chromagram_Mean_9  _Chromagram_Mean_10  \
# count    400.000000  ...          400.000000           400.000000
# mean       0.038307  ...            0.354632             0.590975
# std        0.203754  ...            0.334976             0.357981
# min       -0.916000  ...            0.000000             0.000000
# 25%       -0.078250  ...            0.066750             0.264500
# 50%        0.049500  ...            0.247000             0.612000
# 75%        0.151250  ...            0.612000             1.000000
# max        0.799000  ...            1.000000             1.000000
#
#        _Chromagram_Mean_11  _Chromagram_Mean_12  \
# count           400.000000           400.000000
# mean              0.342340             0.385620
# std               0.315808             0.348117
# min               0.000000             0.000000
# 25%               0.059500             0.060750
# 50%               0.247000             0.296500
# 75%               0.565250             0.670750
# max               1.000000             1.000000
#
#        _HarmonicChangeDetectionFunction_Mean  \
# count                             400.000000
# mean                                0.328213
# std                                 0.055520
# min                                 0.112000
# 25%                                 0.290750
# 50%                                 0.333000
# 75%                                 0.367250
# max                                 0.488000
#
#        _HarmonicChangeDetectionFunction_Std  \
# count                            400.000000
# mean                               0.192997
# std                                0.047092
# min                                0.060000
# 25%                                0.160000
# 50%                                0.190000
# 75%                                0.226000
# max                                0.340000
#
#        _HarmonicChangeDetectionFunction_Slope  \
# count                              400.000000
# mean                                -0.000157
# std                                  0.104743
# min                                 -0.285000
# 25%                                 -0.058000
# 50%                                 -0.002000
# 75%                                  0.063250
# max                                  0.442000
#
#        _HarmonicChangeDetectionFunction_PeriodFreq  \
# count                                   400.000000
# mean                                      1.762288
# std                                       0.930352
# min                                       0.187000
# 25%                                       0.961000
# 50%                                       1.682000
# 75%                                       2.243000
# max                                       4.486000
#
#        _HarmonicChangeDetectionFunction_PeriodAmp  \
# count                                  400.000000
# mean                                     0.769690
# std                                      0.072107
# min                                      0.530000
# 25%                                      0.725000
# 50%                                      0.786000
# 75%                                      0.824000
# max                                      0.908000
#
#        _HarmonicChangeDetectionFunction_PeriodEntropy
# count                                      400.000000
# mean                                        -0.002960
# std                                          0.969091
# min                                         -2.892489
# 25%                                         -0.567814
# 50%                                         -0.029615
# 75%                                          0.574836
# max                                          2.881057
#
# [8 rows x 50 columns]
#
# Features with remaining high skewness (>1 or <-1):
# Series([], dtype: float64)
#
# Features with remaining high kurtosis (>7):
# Series([], dtype: float64)
